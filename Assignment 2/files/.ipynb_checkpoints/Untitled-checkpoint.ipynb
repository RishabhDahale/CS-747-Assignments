# %%
import time
start = time.time()
# !python MazeVerifyOutput.py --algorithm vi
end = time.time()
print(end-start)
# Out:
# test instance 1 ----------------------------------------------------------------------------------------------------
# Executing... python encoder.py --grid data/maze/grid10.txt
# Executing... python planner.py --mdp mdpFile --algorithm vi
# Executing... python decoder.py --grid data/maze/grid10.txt --value_policy value_and_policy_file
# ALL CHECKS PASSED!
# Checking the correctness of you solution...
# OK. You have printed the correct shortest path
#
#
# test instance 2 ----------------------------------------------------------------------------------------------------
# Executing... python encoder.py --grid data/maze/grid20.txt
# Executing... python planner.py --mdp mdpFile --algorithm vi
# Executing... python decoder.py --grid data/maze/grid20.txt --value_policy value_and_policy_file
# ALL CHECKS PASSED!
# Checking the correctness of you solution...
# OK. You have printed the correct shortest path
#
#
# ...

# %%
print(end-start)
# Out:
# 209.61976146697998

# %%
import time
start1 = time.time()
# !python PlannerVerifyOutput.py
end1 = time.time()
print(end1-start1)
# Out:
# verify output hpi
#
#
#  ----------------------------------------------------------------------------------------------------
# test case 1hpi :	 python planner.py --mdp data/mdp/continuing-mdp-10-5.txt --algorithm hpi
# ALL CHECKS PASSED!
# Calculating error of your value function...
#   2.234958   2.234958   0.000000	OK
#   2.373612   2.373612   0.000000	OK
#   2.604046   2.604046   0.000000	OK
#   2.647784   2.647784   0.000000	OK
#   2.522231   2.522231   0.000000	OK
#   2.375252   2.375252   0.000000	OK
#   2.684806   2.684806   0.000000	OK
#   2.688310   2.688310   0.000000	OK
#   2.640809   2.640809   0.000000	OK
#   2.572427   2.572427   0.000000	OK
#
#
#  ----------------------------------------------------------------------------------------------------
# test case 2hpi :	 python planner.py --mdp data/mdp/continuing-mdp-2-2.txt --algorithm hpi
# ALL CHECKS PASSED!
# Calculating error of your value function...
#   5.999300   5.999300   0.000000	OK
# ...

# %%
print(end1-start1)
# Out:
# 18.89950180053711
